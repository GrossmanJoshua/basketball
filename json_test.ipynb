# %%
import json

# %%
with open('jh.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {'parameters': {'AheadBehind': None,
#   'ClutchTime': None,
#   'ContextFilter': '',
#   'ContextMeasure': 'FGA',
#   'DateFrom': None,
#   'DateTo': None,
#   'EndPeriod': None,
#   'EndRange': None,
#   'GameID': None,
#   'GameSegment': None,
#   'LastNGames': 0,
#   'LeagueID': '00',
#   'Location': None,
#   'Month': 0,
#   'OpponentTeamID': 0,
#   'Outcome': None,
#   'Period': 0,
#   'PlayerID': 201935,
#   'PointDiff': None,
#   'Position': None,
#   'RangeType': None,
#   'RookieYear': None,
#   'Season': '2015-16',
#   'SeasonSegment': None,
#   'SeasonType': 'Regular Season',
#   'StartPeriod': None,
#   'StartRange': None,
#   'TeamID': 0,
#   'VsConference': None,
#   'VsDivision': None},
#  'resource': 'shotchartdetail',
#  'resultSets': [{'headers': ['GRID_TYPE',
#     'GAME_ID',
#     'GAME_EVENT_ID',
#     'PLAYER_ID',
#     'PLAYER_NAME',
#     'TEAM_ID',
#     'TEAM_NAME',
#     'PERIOD',
#     'MINUTES_REMAINING',
#     'SECONDS_REMAINING',
#     'EVENT_TYPE',
# ...

# %%
import pandas as pd

# %%
# ?pd.read_json

# %%
df = pd.DataFrame(data['resultSets'][0]['rowSet'],columns=data['resultSets'][0]['headers'])

# %%
df.columns
# Out:
# Index(['GRID_TYPE', 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID', 'PLAYER_NAME',
#        'TEAM_ID', 'TEAM_NAME', 'PERIOD', 'MINUTES_REMAINING',
#        'SECONDS_REMAINING', 'EVENT_TYPE', 'ACTION_TYPE', 'SHOT_TYPE',
#        'SHOT_ZONE_BASIC', 'SHOT_ZONE_AREA', 'SHOT_ZONE_RANGE', 'SHOT_DISTANCE',
#        'LOC_X', 'LOC_Y', 'SHOT_ATTEMPTED_FLAG', 'SHOT_MADE_FLAG', 'GAME_DATE',
#        'HTM', 'VTM'],
#       dtype='object')
