# %% [markdown]
# See: https://www.pro-football-reference.com/blog/index4837.html?p=37

# %%
import srs

# %%
import imp
imp.reload(srs)
# Out:
# <module 'srs' from '/Users/joshuagrossman/Documents/Code/basketball/basketball_git/srs.py'>

# %%
table = srs.load_games(2021, ['december','january','february','march','april'])

# %%
missing = np.array([11, 25, 58, 60, 62]) # 2
missing = np.array([ 2,  8, 10, 11, 12, 13, 20, 21, 22, 24, 25, 28, 32, 34, 43, 57, 58,
       59, 60, 62]) # 2 or 3
table_split = srs.split_team(table, 'Boston Celtics', missing, 'Hospital Celtics')

# %%
srs.get_srs(table_split)
# Out:
#                              srs
# Utah Jazz               8.959173
# Milwaukee Bucks         6.551915
# Los Angeles Clippers    6.238262
# Phoenix Suns            5.511396
# Denver Nuggets          5.019958
# Philadelphia 76ers      4.578293
# Brooklyn Nets           4.080542
# Boston Celtics          3.683743
# Los Angeles Lakers      3.376560
# Dallas Mavericks        2.434808
# Atlanta Hawks           2.003743
# New York Knicks         1.642594
# Memphis Grizzlies       1.556589
# New Orleans Pelicans    0.321603
# Toronto Raptors        -0.033555
# Golden State Warriors  -0.209970
# Portland Trail Blazers -0.276330
# Indiana Pacers         -0.511518
# Miami Heat             -0.789441
# San Antonio Spurs      -0.954504
# Charlotte Hornets      -1.190216
# Chicago Bulls          -1.505225
# Hospital Celtics       -2.036461
# Washington Wizards     -3.287195
# Detroit Pistons        -3.556316
# Sacramento Kings       -3.875415
# Minnesota Timberwolves -6.436346
# ...

# %%
srs.get_srs(table)
# Out:
#                              srs
# Utah Jazz               8.890180
# Milwaukee Bucks         6.459985
# Los Angeles Clippers    6.257541
# Phoenix Suns            5.624175
# Denver Nuggets          4.953344
# Philadelphia 76ers      4.577433
# Brooklyn Nets           4.174935
# Los Angeles Lakers      3.307664
# Dallas Mavericks        2.365443
# Atlanta Hawks           2.087932
# Boston Celtics          1.837519
# New York Knicks         1.671497
# Memphis Grizzlies       1.577303
# New Orleans Pelicans    0.256339
# Toronto Raptors         0.055957
# Golden State Warriors  -0.186250
# Portland Trail Blazers -0.314784
# Indiana Pacers         -0.606659
# Miami Heat             -0.816477
# San Antonio Spurs      -0.995794
# Charlotte Hornets      -1.252859
# Chicago Bulls          -1.480121
# Washington Wizards     -3.193755
# Detroit Pistons        -3.553905
# Sacramento Kings       -3.849456
# Minnesota Timberwolves -6.472266
# Cleveland Cavaliers    -6.766359
# ...
